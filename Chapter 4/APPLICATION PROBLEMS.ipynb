# %%
bold = '\033[1m' 
end = '\033[0m'

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import math
plt.style.use('ggplot')

# %%
prob4_28 = pd.read_excel('Chapter4.xlsx', sheet_name='Prob4_28')

# %%
print(prob4_28.head())
print(prob4_28.shape)
# Out:
#    income_start  income_stop  population_percent
# 0             0          5.0                   4
# 1             5         10.0                  13
# 2            10         15.0                  17
# 3            15         20.0                  20
# 4            20         25.0                  16
# (12, 3)

# %% [markdown]
# # `EXERCISES`

# %% [markdown]
# # Exercise 4.25

# %% [markdown]
# Before an automobile parts manufacturer takes full delivery of polymer resins made by a supplier in a reactive extrusion process, a sample is processed and the performance is tested for `Toughness`. The batch is either accepted (if the processed sample's `Toughness` equals or exceeds 140 $J/m^3$) or it is rejected. As a result of process and raw material variability, the acceptance/rejection status of each batch varies randomly.  If the supplier sends four batches weekly to the parts manufacturer, and each batch is made independently on the extrusion process, so that the ultimate fate of one batch is independent of the fate of any other batch, define $X$ as the random variable representing the number of acceptable batches a week and answer the following questions:
#
# (i) Obtain the sample space, $\Omega$, and the corresponding random variable space, $V$.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# Let $A$ denote Accepted and $R$ denote Rejected batch.
#
# $\Omega = \{ \\
# (A,A,A,A), \\
# (A,A,A,R), \\
# (A,A,R,A), \\
# (A,A,R,R), \\
# (A,R,A,A), \\
# (A,R,A,R), \\
# (A,R,R,A), \\
# (A,R,R,R), \\
# (R,A,A,A), \\
# (R,A,A,R), \\
# (R,A,R,A), \\
# (R,A,R,R), \\
# (R,R,A,A), \\
# (R,R,A,R), \\
# (R,R,R,A), \\
# (R,R,R,R), \\
# \}$
#
# <br>
#
# $V = \{4, 3, 2, 1, 0\} $ - denotes the number of ACCEPTED batches per week.
#
# <hr>

# %% [markdown]
# (ii) First, assume equal probability of acceptance and rejection, and obtain the the pdf, $f(x)$, for the entire sample space.  If, for long term profitability it is necessary that **at least** 3 batches be acceptable per week, what is the probability that the supplier will remain profitable?

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# Let $P_A$ be the probability of Acceptance and $P_R$ be the probability of Rejection.
#
# We know that $P_A + P_R = 1$ and given that $P_A = P_R \, \implies \, P_A = \frac{1}{2} = P_R$.
#
# Also, equal probability of acceptance and rejection $\implies P(K) = \frac{1}{16}$ where $K \in \Omega$
#
# Thus,
#
# $f(x) = \left\{
# \begin{array}{ll}
# \frac{1}{16}; &X = 4 \\
# \frac{4}{16}; &X = 3 \\
# \frac{6}{16}; &X = 2 \\
# \frac{4}{16}; &X = 1 \\
# \frac{1}{16}; &X = 0 \\
# \end{array}
# \right.
# $
#
# OR
#
# $f(x) = $ <sup>4</sup>$C_x \, P_A^{\,x} \, P_R^{\,4-x} \,\,$ where <sup>n</sup>$C_x = \frac{n!}{x! \, (n-x)!}$
#
# $ =$ <sup>4</sup>$C_x \, (0.5)^{\,x} \, (0.5)^{\,4-x} \,\,$
#
# $ = $ <sup>4</sup>$C_x \, (0.5)^{\,4} \,\,$
#
# $ = $ <sup>4</sup>$C_x \, \frac{1}{16} \,\,$
#
# <br>
#
# $P($profit$) = f(3) + f(4)$
#
# $ = \frac{4}{16} + \frac{1}{16}$
#
# $\implies P($profit$) = \frac{5}{16}$
#
# <hr>

# %% [markdown]
# # Exercise 4.26

# %% [markdown]
# Revisit Problem 4.25 above and consider that after an extensive process and control system improvement project, the probability of acceptance of a single batch is improved to 0.8; obtain the new pdf, $f(x)$. If the revenue from a single acceptable batch is \$20,000, but every rejected batch costs the supplier \$8,000 in retrieval and incineration fees, which will be deducted from the revenue, what is the expected net revenue per week under the current circumstances?

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# New pdf:
#
# $f(x) = $ <sup>4</sup>$C_x \, P_A^{\,x} \, P_R^{\,4-x}$
#
# $f(x) = $ <sup>4</sup>$C_x \, 0.8^{\,x} \, 0.2^{\,4-x}$
#
# <br>
#
# Now,
#
# $E(X) = \sum x \cdot f(x)$
#
# $ = 0 \times 1 \times 0.8^0 0.2^4 + 1 \times 4 \times 0.8^1 0.2^3 + 2 \times 6 \times 0.8^2 0.2^2 + 3 \times 4 \times 0.8^3 0.2^1 + 4 \times 1 \times 0.8^4 0.2^0$
#
# $ = 0 + 0.0256 + 0.3072 + 1.2288 + 1.6384$
#
# $\implies E(X) = 3.2$
#
# <br>
#
# Let $G(X)$ be the net revenue per week defined as
#
# $ G(X) = \$ 20000x - \$ 8000 (4-x) = \$28000x - \$ 32000$
#
# So,
#
# The expected value of net revenue generated per week is given by:
#
# $E[G(X)] = E(\$ 28000X - \$ 32000)$
#
# $= \$ 28000 E(X) - \$ 32000$
#
# $ = \$ 28000 \times 3.2 - \$ 32000$
#
# $ = \$ 57600$
#
# <hr>

# %% [markdown]
# # Exercise 4.27

# %% [markdown]
# A gas station situated on a back country road has only one
# gasoline pump and one attendant and, on average, receives $\eta = 3$
# (cars/hour).  The average rate at which this lone attendant services the cars is
# $\zeta$ (cars/hour).  It can be shown that the total number of cars at this gas
# station at any time (i.e. the one currently being served, and those waiting in
# line to be served) is the random variable $X$ with the following pdf:
#
# $$
# f(x) = \left( 1 - \frac{\eta}{\zeta} \right) \left( \frac{\eta}{\zeta}\right)^x;
# \; x = 0,1,2, \ldots
# $$
#
# (i) Show that so long as $\eta < \zeta$, the probability that the line at the
# gas station is infinitely long is **zero**.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# $f(x) = \left( 1 - \frac{\eta}{\zeta} \right) \left( \frac{\eta}{\zeta}\right)^x$
#
# At $x = \infty$:
#
# $f(\infty) = \left( 1 - \frac{\eta}{\zeta} \right) \left( \frac{\eta}{\zeta}\right)^{\infty}$
#
# Given $\eta < \zeta \implies \frac{\eta}{\zeta} < 1 \implies \left(\frac{\eta}{\zeta}^{\infty}\right) \approx 0$:
#
# $\implies f(\infty) = \left( 1 - \frac{\eta}{\zeta} \right) \times 0$
#
# $\implies f(\infty) = 0$
#
# <hr>

# %% [markdown]
# (ii) Find the value of $\zeta$ required so that the expected value of the total
# number of cars at the station is 2.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# $E(X) = \sum_{x= -\infty}^{\infty} f(x) \cdot x$
#
# $ = \sum_{x=0}^{\infty} \left( 1 - \frac{\eta}{\zeta} \right) \left( \frac{\eta}{\zeta}\right)^x \cdot x$
#
# Let $\frac{\eta}{\zeta} = p$:
#
# $ = \sum_{x=0}^{\infty} (1 - p) p^x \cdot x$
#
# $ = \sum_{x=0}^{\infty} (x p^x - x p^{(x+1)})  $
#
# <br>
#
# We know $\sum_0^{\infty} x^n = \frac{1}{1 - x} \,\,\,$ (sum of a GP)
#
# $\implies \frac{d}{dx} \left(\sum_0^{\infty} x^n \right) = \frac{d}{dx} \left(\frac{1}{1 - x} \right)$
#
# $\implies \sum_0^{\infty} \frac{d}{dx} \left( x^n \right) = \frac{d}{dx} \left(\frac{1}{1 - x} \right)$
#
# $\implies \sum_0^{\infty} n (x^{n-1}) = \frac{1}{(1 - x)^2} $
#
# Multiplying both sides by $x$:
#
# $\implies \sum_0^{\infty} n (x^{n}) = \frac{x}{(1 - x)^2} $
#
# <br>
#
# Also, $\sum_0^{\infty} x^{n+2} = \frac{x^2}{1-x} \,\,\,$ (sum of GP)
#
# $\implies \frac{d}{dx} \left(\sum_0^{\infty} x^{n+2} \right) = \frac{d}{dx} \left(\frac{x^2}{1-x} \right)$
#
# $\implies \sum_0^{\infty} \frac{d}{dx} \left( x^{n+2} \right) = \frac{d}{dx} \left(\frac{x^2}{1-x} \right)$
#
# $\implies \sum_0^{\infty} (n+2) (x^{n+1}) = 2x \left(\frac{1}{(1 - x)} \right) + \frac{x^2}{(1-x)^2}$
#
# $\implies \sum_0^{\infty} n x^{n+1} + 2 \sum_0^{\infty} x^{n+1} = \frac{2x - x^2}{(1 - x)^2}$
#
# $\implies \sum_0^{\infty} n x^{n+1} = \frac{2x - x^2}{(1 - x)^2} - 2 \sum_0^{\infty} x^{n+1}$
#
# $\implies \sum_0^{\infty} n x^{n+1} = \frac{2x - x^2}{(1 - x)^2} - \frac{2x}{1-x}$
#
# $\implies \sum_0^{\infty} n x^{n+1} = \frac{x^2}{(1 - x)^2}$
#
# <br>
#
# Putting the above 2 results in $E(X)$:
#
# $\implies E(X) = \frac{p}{(1 - p)^2} - \frac{p^2}{(1 - p)^2}$
#
# $ = \frac{p - p^2}{(1 - p)^2}$
#
# $ = \frac{p}{1 - p}$
#
# Putting $p = \frac{\eta}{\zeta}$:
#
# $\implies E(X) = \frac{\eta}{\zeta - \eta}$
#
# <br>
#
# Given $\eta = 3$ and $E(X) = 2 \implies \frac{\eta}{\zeta - \eta} = 2$
#
# $\implies 3 = 2(\zeta - 3)$
#
# $\implies \zeta = \frac{9}{2} = 4.5$
#
# <hr>

# %% [markdown]
# (iii) Using the $\zeta$ value obtained in (ii), find the probability that there are **more than** two cars at the station, and also the probability that there are **no** cars.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# $F(x) = \sum_{-\infty}^{x} f(x)$
#
# $ = \sum_{0}^{x} \left( 1 - \frac{\eta}{\zeta} \right) \left( \frac{\eta}{\zeta}\right)^x$
#
# At $\eta = 3$ and $\zeta = 4.5$, $\frac{\eta}{\zeta} = \frac{2}{3}$
#
# $\implies F(x) = \sum_{0}^{x} \left( 1 - \frac{2}{3} \right) \left( \frac{2}{3}\right)^x$
#
# $ =  \frac{1}{3} \sum_{0}^{x} \left( \frac{2}{3}\right)^x$
#
# $ =  \frac{1}{3} \left(\frac{1 - \frac{2}{3}^{(x+1)}}{1 - \frac{2}{3}} \,\,\right)$
#
# $\implies F(x) = 1 - \frac{2}{3}^{x+1}$
#
# <br>
#
# $P(X > 2) = 1 - F(1)$
#
# $ = 1 - \left( 1 - \frac{2}{3}^{(1 + 1)} \right)$
#
# $ = 1 - 1 + \frac{4}{9} $
#
# $\implies P(X > 2) = \frac{4}{9}$
#
# <br>
#
# $P(X = 0) = f(0)$
#
# $ = \left( 1 - \frac{2}{3} \right) \left( \frac{2}{3}\right)^0$
#
# $ = 1 - \frac{2}{3}$
#
# $\implies P(X = 0) = \frac{1}{3} = 0.333$
#
# OR
#
# $P(X = 0) = F(0)$
#
# $ = 1 - \frac{2}{3}^{(0 + 1)}$
#
# $ = 1 - \frac{2}{3} $
#
# $\implies P(X = 0) = \frac{1}{3}$
#
# <hr>

# %% [markdown]
# # Exercise 4.28

# %% [markdown]
# The distribution of income of families in the US in 1979 (in actual dollars uncorrected for inflation) is shown in the table below:
#
# <table><tr><td><img src="Prob4_28.png" width=400></td></tr></table>
#
#
# (i) Plot the data histogram and comment on the shape.

# %%
plt.bar(
    np.arange(0, 60, 5),
    prob4_28['population_percent'], 
    width=4.8,
    label='population_percent'
)

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# > #### `Observations:`
# > The above histogram is right skewed (has a longer right tail). Looking at it suggests that mean sould be somewhere around \$20,000 and the most frequent value lies in the range \$15,000 - \$20,000.
#
# <hr>

# %% [markdown]
# (ii) Using the center of the interval to represent each income group, determine the mean, median, mode; and the variance and skewness for this data set.  Comment on how consistent the numerical values computed for these characteristics are with the shape of the histogram.

# %%
prob4_28['income_centre'] = prob4_28['income_start'] + 2.5
prob4_28[['income_centre', 'population_percent']]
# Out:
#     income_centre  population_percent
# 0             2.5                   4
# 1             7.5                  13
# 2            12.5                  17
# 3            17.5                  20
# 4            22.5                  16
# 5            27.5                  12
# 6            32.5                   7
# 7            37.5                   4
# 8            42.5                   3
# 9            47.5                   2
# 10           52.5                   1
# 11           57.5                   1

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# **Mean**
#
# $\mu = 2.5 \left(\frac{4}{100}\right) + 7.5 \left(\frac{13}{100}\right) + 12.5 \left(\frac{17}{100}\right) + 17.5 \left(\frac{20}{100}\right) + 22.5 \left(\frac{16}{100}\right) + 27.5 \left(\frac{12}{100}\right) + 32.5 \left(\frac{7}{100}\right) + 37.5 \left(\frac{4}{100}\right) + 42.5 \left(\frac{3}{100}\right) + 47.5 \left(\frac{2}{100}\right) + 52.5 \left(\frac{1}{100}\right) + 57.5 \left(\frac{1}{100}\right) $
#
# $ = 0.1 + 0.975 + 2.125 + 3.5 + 3.6 + 3.3 + 2.275 + 1.5 + 1.275 + 0.95 + 0.525 + 0.575 $
#
# $\implies \mu = 20.7 = \$20,700 $
#
# <br>
#
# **Median**
#
# Median is the value $x_m$ for which $P(X \ge x_m) \ge \frac{1}{2}$ and $P(X \le x_m) \ge \frac{1}{2}$
#
# For the given case, $x_m = 17.5 = \$17,500$.
#
# $P(X \ge 17.5) = \frac{20}{100} + \frac{16}{100} + \frac{12}{100} + \frac{7}{100} + \frac{4}{100} + \frac{3}{100} + \frac{2}{100} + \frac{1}{100} + \frac{1}{100}$
#
# $\implies P(X \ge 17.5) = \frac{66}{100}$
#
# And,
#
# $P(X \le 17.5) = \frac{4}{100} + \frac{13}{100} + \frac{17}{100} + \frac{20}{100}$
#
# $\implies P(X \le 17.5) = \frac{54}{100}$
#
# <br>
#
# **Mode**
#
# Mode is the value with the highest frequency. Thus, mode = $17.5 = \$ 17,500$.
#
# <br>
#
# **Variance**
#
# $Var(X) = \sum (x - \mu)^2 \cdot f(x)$
#
# $ = (2.5 - 17.5)^2 \left(\frac{4}{100}\right) + (7.5 - 17.5)^2 \left(\frac{13}{100}\right) + (12.5 - 17.5)^2 \left(\frac{17}{100}\right) + (17.5 - 17.5)^2 \left(\frac{20}{100}\right) + (22.5 - 17.5)^2 \left(\frac{16}{100}\right) + (27.5 - 17.5)^2 \left(\frac{12}{100}\right) + (32.5 - 17.5)^2 \left(\frac{7}{100}\right) + (37.5 - 17.5)^2 \left(\frac{4}{100}\right) + (42.5 - 17.5)^2 \left(\frac{3}{100}\right) + (47.5 - 17.5)^2 \left(\frac{2}{100}\right) + (52.5 - 17.5)^2 \left(\frac{1}{100}\right) + (57.5 - 17.5)^2 \left(\frac{1}{100}\right) $
#
# $ = 9 + 13 + 4 + 0 + 4 + 12 + 15 + 16 + 18 + 12 + 16$
#
# $\implies Var(X) = 139$
#
# <br>
#
# **Standard Deviation**
#
# $\sigma = \sqrt{Var(X)}$
#
# $ = \sqrt{139}$
#
# $\implies \sigma = 11.789 = \$11,789$
#
# <br>
#
# **Skewness**
#
# $\mu_3 = \sum (x - \mu)^3 \cdot f(x)$
#
# $ = (2.5 - 17.5)^3 \left(\frac{4}{100}\right) + (7.5 - 17.5)^3 \left(\frac{13}{100}\right) + (12.5 - 17.5)^3 \left(\frac{17}{100}\right) + (17.5 - 17.5)^3 \left(\frac{20}{100}\right) + (22.5 - 17.5)^3 \left(\frac{16}{100}\right) + (27.5 - 17.5)^3 \left(\frac{12}{100}\right) + (32.5 - 17.5)^3 \left(\frac{7}{100}\right) + (37.5 - 17.5)^3 \left(\frac{4}{100}\right) + (42.5 - 17.5)^3 \left(\frac{3}{100}\right) + (47.5 - 17.5)^3 \left(\frac{2}{100}\right) + (52.5 - 17.5)^3 \left(\frac{1}{100}\right) + (57.5 - 17.5)^3 \left(\frac{1}{100}\right) $
#
# $ = -135 - 130 - 21.25 - 0 + 20 + 120 + 236.25 + 320 + 468.75 + 540 + 428.75 + 640$
#
# $\implies \mu_3 = 2487.5$
#
# $\gamma = \frac{\mu_3}{\sigma^3}$
#
# $\implies \gamma = \frac{2487.5}{(11.789)^3} = 1.51$
#
# <hr>

# %% [markdown]
# (iii)  If the 1979 population is broadly classified according to income into `Lower Class` for income range (in thousands of dollars) 0--15, `Middle Class` for income range, 15--50 and `Upper Class` for income range $> 50$, what is the probability that two people selected at random and sequentially to participate in a survey from the Census Bureau (in preparation for the 1980 census) are:
# 1. both from the `Lower Class,`
# 2. both from the `Middle Class,`
# 3. one from the `Middle class` and one from the `Upper class,` and
# 4. both from the `Upper class`?

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# **1.**
# P(both from LOWER class) = $0.34 * 0.34 = 0.1156$
#
# **2.**
# P(both from MIDDLE class) = $0.64 * 0.64 = 0.4096$
#
# **3.**
# P(one from MIDDLE class, one from UPPER class) = $2 * 0.64 * 0.02 = 0.0256$
#
# **4.**
# P(both from UPPER class) = $0.02 * 0.02 = 0.0004$
#
# <hr>

# %% [markdown]
# (iv) If, in 1979, engineers with **at least** 3 years of college education (excluding graduate students) constitute approximately 1% of the population, (2.2 million out of 223 million) and span the income range from 20--55, determine the probability that an individual selected at random from the population is in the middle class given that he/she is an engineer.  Determine the converse, that the person selected at random is an engineer given that he/she is in the middle class.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
#
#
# <hr>

# %% [markdown]
# # Exercise 4.29

# %% [markdown]
# Life-testing results on a first generation microprocessor-based (computer-controlled) toaster indicate that $X$, the life-span (in years) of the central control chip, is a random variable that is reasonably well-modeled by the pdf:
#
# $$
# f(x) = \frac{1}{\beta} e^{- x/\beta}; x > 0
# $$
#
# with $\beta = 6.25$. A malfunctioning chip will have to be replaced
# to restore proper toaster operation.
#
# (i) The warranty for the chip is to be set at $x_w$ years (in whole integers) such that no
# more than $15\%$ would have to be replaced before the warranty period expires.  Find $x_w$.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# We are looking for a value $x_m$ such that no more than $15\%$ chips fail before $x_m$ years. In other words, we are looking for a value $x_m$ such that at least $85\%$ chips **survives** $x_m$ years or more.
#
# $\implies S(x) = \int_{x_m}^\infty \frac{1}{\beta}e^{-x/\beta} \, dx $
#
# $ = \frac{1}{\beta} \int_{x_m}^\infty e^{-x/\beta} \, dx $
#
# $ = \frac{1}{\beta} \left[\frac{e^{-x/\beta}}{-1/\beta}\right]_{x_m}^\infty$
#
# $ = \left[- e^{-x/\beta}\right]_{x_m}^\infty$
#
# $ = \left(- e^{-\infty/\beta}\right) - \left(- e^{-x_m/\beta}\right)$
#
# $\implies S(x) = e^{-x_m/\beta}$
#
# <br>
#
# Putting $\beta = 6.25$ and $S(x) = 0.85$:
#
# $\implies  e^{-x_m/6.25} = 0.85$
#
# Taking $\log$ on both sides:
#
# $\implies  - \frac{x_m}{6.25} = \log(0.85)$
#
# $\implies  x_m = (-0.1625) \times (-6.25)$
#
# $\implies  x_m = 1.01 \approx 1$ year
#
# <hr>

# %% [markdown]
# (ii) In planning for the second generation toaster, design engineers wish to set a target value to aim for ($\beta=\beta_2^*$)  such that $85\%$ of the second generation chips survive beyond 3 years. Determine $\beta_2^*$ and interpret your results in terms of the implied `fold increase` in mean life-span from the first to the second generation of chips.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# We have to find a $\beta_2^*$ such that $S(3) = 0.85$
#
# $\implies e^{-3/\beta_2^*} = 0.85$
#
# Taking $\log$ on both sides:
#
# $\implies -3/\beta_2^* = \log(0.85)$
#
# $\implies \frac{-3}{-0.1625} = \beta_2^*$
#
# $\implies \beta_2^* = 18.4615$
#
# > #### `Observations:`
# > On increasing $\beta$ 3-folds, we see that the mean life-span of chips also increased 3-folds.
#
# <hr>

# %% [markdown]
# # Exercise 4.30

# %% [markdown]
# The probability of a single transferred embryo resulting in a live birth in an in-vitro fertilization treatment, $p$, is given as 0.5 for a younger patient and 0.2 for an older patient.  When $n=5$ embryos are transferred in a single treatment, it is also known that if $X$ is the total number of live births resulting from this treatment, then $E(X) = 2.5$ for the younger patient and $E(X) =1$ for the older patient, and the associated variance, $Var(X) = 1.25$ for the younger and $Var(X) = 0.8$ for the older.
#
# (i) Use Markov's inequality and Chebyshev's inequality to obtain bounds on the probability of each patient giving birth to quadruplets or a quintuplets at the end of the treatment.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# **Markov's Inequality :**
#
# $P(X \ge c) \le \frac{E(X)}{c}$
#
# <br>
#
# 1. Younger People
#
#     $P(X \ge 4) \le \frac{2.5}{4} \implies P(X \ge 4) \le 0.625$
#
#     <br>
#
# 2. Older People
#
#     $P(X \ge 4) \le \frac{1}{4} \implies P(X \ge 4) \le 0.25 $ <br> <br>
#
#
# <br>
#
# **Chebychev’s Inequality :**
#
# $P[(X - \mu)^2 \ge k^2\sigma^2)] \le \frac{1}{k^2}$
#
# $\implies P(\,|X - \mu| \ge k\sigma) \le \frac{1}{k^2}$
#
# <br>
#
# 1. Younger People
#
#     $X \ge 4 \implies (X - 2.5) \ge 4-2.5$
#
#     $\implies k\sigma = 1.5$
#
#     $\implies k\sqrt{1.25} = 1.5$
#
#     $\implies k = \frac{1.5}{\sqrt{1.25}}$
#
#     $\implies P(\,|X - 2.5| \ge 1.5) \le \left(\frac{\sqrt{1.25}}{1.5}\right)^2 = 0.5555$
#
#     $\implies  P(X \ge 4) \le 0.55555$ <br> <br>
#
#     <br>
#
# 2. Older People
#
#     $X \ge 4 \implies (X - 1) \ge 4 - 1$
#
#     $\implies k\sigma = 3$
#
#     $\implies k\sqrt{0.8} = 3$
#
#     $\implies k = \frac{3}{\sqrt{0.8}}$
#
#     $\implies P(\,|X - 1| \ge 3) \le \left(\frac{\sqrt{0.8}}{3}\right)^2 = 0.08888$
#
#     $\implies  P(X \ge 4) \le 0.08888$ <br> <br>
#
# <hr>

# %% [markdown]
# (ii) These bounds are known to be quite conservative, but to determine just how conservative , compute the actual probabilities of the stated events for each patient given that an appropriate pdf for $X$ is
#
# $$
# f(x) = \frac{5!}{x!(5-x)!}p^{x}(1-p)^{5-x}
# $$
#
# where $p$ is as given above.  Compare the actual probabilities with the Markov and Chebychev bounds and identify which bound is sharper.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# $P(X \ge 4) = P(X = 4) + P(X = 5) $
#
# <br>
#
# 1. **Younger People** ($p = 0.5$):
#
#     $P(X=4) = f(4)$
#
#     $ = \frac{5!}{4!(5-4)!}(0.5)^{4}(1-0.5)^{5-4}$
#
#     $ = 5 \times (0.5)^{5}$
#
#     $\implies P(X=4) = 0.15625$
#
#     <br>
#
#     $P(X=5) = f(5)$
#
#     $ = \frac{5!}{5!(5-5)!}(0.5)^{5}(1-0.5)^{5-5}$
#
#     $ = (0.5)^{5}$
#
#     $\implies P(X=5) = 0.03125$
#
#     <br>
#
#     $\implies P(X \ge 4) = 0.15625 + 0.03125 = 0.1875$
#
#     <br>
#
# 2. **Older People** ($p = 0.2$):
#
#     $P(X=4) = f(4)$
#
#     $ = \frac{5!}{4!(5-4)!}(0.2)^{4}(1-0.2)^{5-4}$
#
#     $ = 5 \times (0.2)^{4} \times 0.8$
#
#     $\implies P(X=4) = 0.0064$
#
#     <br>
#
#     $P(X=5) = f(5)$
#
#     $ = \frac{5!}{5!(5-5)!}(0.2)^{5}(1-0.2)^{5-5}$
#
#     $ = (0.5)^{5}$
#
#     $\implies P(X=5) = 0.00032$
#
#     <br>
#
#     $\implies P(X \ge 4) = 0.0064 + 0.00032 = 0.00672$
#
# > #### `Observation:`
# > The probability bounds given by both Markov's Inequality and Chebychev's Inequality are more than 3-folds greater than the actual values for younger people and more than 10-folds greater than the actual probability for older people. Comparatively though, Chebychev's bounds are much sharper than those obtained from Markov's.
#
# <hr>

# %% [markdown]
# # Exercise 4.31

# %% [markdown]
# The following data table, obtained from the United States Life Tables 1969--71, (published in 1973 by the National Center for Health Statistics) shows the probability of survival until the age of 65 for individuals of the given age:
#
# <table><tr><td><img src="Prob4_31.png" width=250></td></tr></table>
#
# The data should be interpreted as follows: the probability that all newborns, and children up to the age of ten survive until 65 years of age is 0.72; for those older than 10 and up to 20 years, the probability of survival to 65 years is 0.74, and so on.
#
# Assuming that the data is still valid in 1975, a community cooperative wishes to set up a life insurance program that year whereby each participant pays a relatively small annual premium, $\$\alpha$, and, in the event of death before 65 years, a one-time death gratuity payment of  $\$\pi$ is made to the participant's designated beneficiary. If the participant survives beyond 65 years, nothing is paid.  If the cooperative is to realize a fixed, modest expected revenue, $\$R_E = \$30$, per year, per participant, over the duration of his/her participation (mostly to cover administrative and other costs) provide answers to the following questions:
#
# (i) For a policy based on a fixed annual premium of \$90 for all participants, and age-dependent payout, determine values for $\pi(y)$, the published payout for a person of age $y$ that dies before age 65, for all values of $y$ listed in this table.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
# Given $E(R) = 30$
#
# $\implies (p)(\alpha) + (1-p) \frac{- \pi}{x} = 30$
#
# $\implies (p)(x \alpha) + (1-p) (- \pi) = 30x$
#
# where $p$ = probability of survival, $x$ = number of years of participation
#
# <br>
#
# 1. $y = 0$, $x = 65$, $p = 0.72$
#
#     $\implies (0.72)(65 \times 90) + (1-0.72) (-\pi) = 30 \times 65$
#
#     $\implies 4212 - 1950 = 0.28 \pi$
#
#     $\implies \pi = \frac{2262}{0.28}$
#
#     $\implies \pi = 8078.5$
#
#     <br>
#
# 2. $y = 10$, $x = 55$, $p = 0.74$
#
#     $\implies (0.74)(55 \times 90) + (1-0.74) (-\pi) = 30 \times 55$
#
#     $\implies 3663 - 1650 = 0.26 \pi$
#
#     $\implies \pi = \frac{2013}{0.26}$
#
#     $\implies \pi = 7742.3$
#
#     <br>
#
# 3. $y = 20$, $x = 45$, $p = 0.74$
#
#     $\implies (0.74)(45 \times 90) + (1-0.74) (-\pi) = 30 \times 45$
#
#     $\implies 2997 - 1350 = 0.26 \pi$
#
#     $\implies \pi = \frac{1647}{0.26}$
#
#     $\implies \pi = 6334.6$
#
#     <br>
#
# 4. $y = 30$, $x = 35$, $p = 0.75$
#
#     $\implies (0.75)(35 \times 90) + (1-0.75) (-\pi) = 30 \times 35$
#
#     $\implies 2362.5 - 1050 = 0.28 \pi$
#
#     $\implies \pi = \frac{2262}{0.28}$
#
#     $\implies \pi = 5250$
#
#     <br>
#
# 5. $y = 35$, $x = 30$, $p = 0.76$
#
#     $\implies (0.76)(30 \times 90) + (1-0.76) (-\pi) = 30 \times 30$
#
#     $\implies 4212 - 1950 = 0.28 \pi$
#
#     $\implies \pi = \frac{2262}{0.28}$
#
#     $\implies \pi = 8078.5$
#
#     <br>
#
# 6. $y = 40$, $x = 25$, $p = 0.77$
#
#     $\implies (0.72)(65 \times 90) + (1-0.72) (-\pi) = 30 \times 65$
#
#     $\implies 4212 - 1950 = 0.28 \pi$
#
#     $\implies \pi = \frac{2262}{0.28}$
#
#     $\implies \pi = 8078.5$
#
#     <br>
#
# 7. $y = 45$, $x = 20$, $p = 0.79$
#
#     $\implies (0.72)(65 \times 90) + (1-0.72) (-\pi) = 30 \times 65$
#
#     $\implies 4212 - 1950 = 0.28 \pi$
#
#     $\implies \pi = \frac{2262}{0.28}$
#
#     $\implies \pi = 8078.5$
#
#     <br>
#
# 8. $y = 50$, $x = 15$, $p = 0.81$
#
#     $\implies (0.72)(65 \times 90) + (1-0.72) (-\pi) = 30 \times 65$
#
#     $\implies 4212 - 1950 = 0.28 \pi$
#
#     $\implies \pi = \frac{2262}{0.28}$
#
#     $\implies \pi = 8078.5$
#
#     <br>
#
# 9. $y = 55$, $x = 10$, $p = 0.85$
#
#     $\implies (0.72)(65 \times 90) + (1-0.72) (-\pi) = 30 \times 65$
#
#     $\implies 4212 - 1950 = 0.28 \pi$
#
#     $\implies \pi = \frac{2262}{0.28}$
#
#     $\implies \pi = 8078.5$
#
#     <br>
#
# 10. $y = 60$, $x = 5$, $p = 0.90$
#
#     $\implies (0.72)(65 \times 90) + (1-0.72) (-\pi) = 30 \times 65$
#
#     $\implies 4212 - 1950 = 0.28 \pi$
#
#     $\implies \pi = \frac{2262}{0.28}$
#
#     $\implies \pi = 8078.5$
#
# <hr>

# %% [markdown]
# (ii) For a policy based instead on a fixed death payout of $\$8,000$, and age-dependent annual premiums,  determine values for $\alpha(y)$, the published annual premium to be collected each year from a participant of age $y$.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
#
#
# <hr>

# %% [markdown]
# (iii) If it becomes necessary to increase the expected revenue by $50\%$ as a result of increased administrative and overhead costs, determine the effect on each of the policies in (i) and (ii) above.

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
#
#
# <hr>

# %% [markdown]
# (iv) If by 1990, the probabilities of survival have increased across the board by 0.05, determine the effect on each of the policies in (i) and (ii).

# %% [markdown]
# <hr>
# <span style="color: #990033;">
#
# ### `Solution:`
#
#
#
# <hr>
